# %%
import cv2
import pandas as pd
from PIL import Image
from IPython.display import Image

# In this notebook, visualizations can be seen for both the gmapping and rtabmap planners. The planners show the thought 
# process of the car and aims to visualize where the algorithm believes the car should move to move from point A to point B.

# %%
# gmapping planner
Image("gmapping_planners.PNG")

# %%
# rtab planner
Image("rtab_planners.PNG")
